# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Milica Ušljebrka__
# <br>Transfer pricing consultant

# %% [markdown]
# _I am interested in data science because I belive data and insights we can get from it are the future of every industry in modern economy._

# %% [markdown]
# ### My code is supposed to perfom simple calculation and print our reslt allong with short message

# %%
print ("Hi! My code can combine string and integer: 1+1 equals ",1+1);
# Out:
# Hi! My code can combine string and integer: 1+1 equals  2

# %% [markdown]
# This is non-creative person's table:<br>
#
# | column 1 | column 2 |
# | ----- | ----- |
# | row1 | smth |
# | row2 | smth |
#
# <br>This is a bullet list<br>
# - item 1
# - item 2
# - item 3
#
# <br>This is a number list <br>
# 1. item 1
# 2. item 2
# 3. item 3
